# %%
# Import libraries
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../datasets/data_dc4_p1.csv', sep=';', header=None)

df
# Out:
#                                                  0
# 0                                          x1,x2,y
# 1     -0.46595006215739326,0.03526015481369809,0.0
# 2      -0.07735580603232463,0.2998513233653449,0.0
# 3      -0.3054980027740006,0.38088236137278614,0.0
# 4      -1.7081686604549648,-1.1839244178270154,0.0
# ...                                            ...
# 1996    1.7618828365105579,-1.2595816434265183,3.0
# 1997     2.177915718199447,-0.3055834523670982,3.0
# 1998    2.0630731847107238,0.12535659724611137,3.0
# 1999    1.8277943920763362,-1.0111478644467786,3.0
# 2000    2.253063299325383,0.044115606418037606,3.0
#
# [2001 rows x 1 columns]

# %%
df.columns
# Out:
# Index([0], dtype='int64')

# %%
df.dtypes
# Out:
# 0    object
# dtype: object

# %%
# The data is comma-separated, not semicolon-separated
df = pd.read_csv('../datasets/data_dc4_p1.csv', sep=',', header=0)

# Check the result
print(df.head())
print(f"Number of columns: {len(df.columns)}")
print(f"Column names: {df.columns.tolist()}")
# Out:
#          x1        x2    y
# 0 -0.465950  0.035260  0.0
# 1 -0.077356  0.299851  0.0
# 2 -0.305498  0.380882  0.0
# 3 -1.708169 -1.183924  0.0
# 4 -2.014558 -1.771395  0.0
# Number of columns: 3
# Column names: ['x1', 'x2', 'y']

# %%
# Create scatterplot
sns.scatterplot(data=df, x='x1', y='x2', hue='y', palette='deep')
plt.title('Scatterplot of x1 vs x2')

# %%
sns.pairplot(df, hue='y', palette='deep')

# %%
df2 = pd.read_csv('../datasets/data_dc4_p2.csv', sep=';', header=None)

df2
# Out:
#                                                 0
# 0                                         x1,x2,y
# 1                    -8.2,-8.2,152.22388944593092
# 2       -8.117587939698492,-8.2,150.7550051376331
# 3      -8.035175879396984,-8.2,150.43500682424252
# 4      -7.952763819095477,-8.2,146.10184976197542
# ...                                           ...
# 39996     7.870351758793969,8.2,144.5869836358454
# 39997    7.952763819095477,8.2,142.74165945326772
# 39998    8.035175879396984,8.2,147.25005202104944
# 39999     8.117587939698492,8.2,153.9875925474852
# 40000                    8.2,8.2,153.228552191337
#
# [40001 rows x 1 columns]

# %%
df2.columns
# Out:
# Index([0], dtype='int64')

# %%
df2.dtypes
# Out:
# 0    object
# dtype: object

# %%
# The data is comma-separated, not semicolon-separated
df2 = pd.read_csv('../datasets/data_dc4_p1.csv', sep=',', header=0)

# Check the result
print(df2.head())
print(f"Number of columns: {len(df2.columns)}")
print(f"Column names: {df2.columns.tolist()}")
# Out:
#          x1        x2    y
# 0 -0.465950  0.035260  0.0
# 1 -0.077356  0.299851  0.0
# 2 -0.305498  0.380882  0.0
# 3 -1.708169 -1.183924  0.0
# 4 -2.014558 -1.771395  0.0
# Number of columns: 3
# Column names: ['x1', 'x2', 'y']

# %%
# Create scatterplot
sns.scatterplot(data=df2, x='x1', y='x2', hue='y', palette='deep')
plt.title('Scatterplot of x1 vs x2')
plt.xlabel('x1')
plt.ylabel('x2')
plt.show()
